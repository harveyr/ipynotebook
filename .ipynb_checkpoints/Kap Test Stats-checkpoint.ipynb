# %%
from IPython.display import HTML, display
from string import Template

attempts = []
summaries = {}

student_a = "Student A"
student_b = "Student B"
student_c = "Student C"

dimensions = {
    'qbank': {
        'test_type': 'qbank',
        'questions': [1, 2, 3, 4]
    },
    'fixed': {
        'test_type': 'fixed',
        'questions': [1, 2, 3, 4]
    }
}


class TestStats:
    def __init__(self):
        self.answered = 0
        self.incorrect = 0
        self.seconds = 0

    def __str__(self):
        return '<TestStats: {}/{} ({} s)>'.format(
            self.correct,
            self.answered,
            self.seconds)

    def add(self, stats):
        self.answered += stats.answered
        self.incorrect += stats.incorrect
        self.seconds += stats.seconds

    @property
    def correct(self):
        return self.answered - self.incorrect

    @property
    def score(self):
        return int(100 * float(self.correct) / float(self.answered))

    @property
    def secondsPerQuestion(self):
        return self.seconds / self.answered


class TestAttempt(TestStats):

    def __init__(self, name, dimension, answers, seconds):
        self.name = name
        self.answers = answers
        self.answered = len(answers)
        self.incorrect = len([q for q in answers if not q])
        self.seconds = seconds
        self.dimension = dimension


def print_stat(key, val):
    tabs = '\t'
    if len(key) < 6:
        tabs += '\t' 
    print("|\t{}:{}{}".format(key, tabs, val))

def combined_stats(stats_list):
    combined = TestStats()
    combined.answered = sum([s.answered for s in stats_list])
    combined.incorrect = sum([s.incorrect for s in stats_list])
    combined.seconds = sum([s.seconds for s in stats_list])
    return combined

def global_stats():
    gs = TestStats()
    summarized = [v for k, v in summaries.iteritems()]
    gs.answered = sum([a.answered for a in summarized])
    gs.incorrect = sum([a.incorrect for a in summarized])
    gs.seconds = sum([a.seconds for a in summarized])
    return gs

def student_stats_for_type(name, test_type):
    atts = []
    for a in attempts:
        if a.name == name and dimensions[a.dimension]['test_type'] == test_type:
            atts.append(a)
    return combined_stats(atts)

def global_stats_for_test_type(test_type):
    gs = TestStats()
    dims = []
    for dim_name in dimensions:
        if dimensions[dim_name]['test_type'] == test_type:
            dims.append(dim_name)
    atts = [a for a in attempts if a.dimension in dims]
    return combined_stats(atts)
    

def print_stats_vs_global(stats_list):
    gs = global_stats()
    row_template = Template("""
        <tr>
            <td> $label </td>
            <td> $answered </td>
            <td> $correct </td>
            <td> $score </td>
            <td style="$devStyle"><em>$scoreDev</em></td>
            <td> $seconds </td>
            <td> $secPerQuestion </td>
        </tr>
    """)

    html = """
    <table>
        <tr>
            <th> Stats </th>
            <th> Answered </th>
            <th> Correct </th>
            <th> Score </th>
            <th> <em>(Deviation)</em> </th>
            <th> Seconds </th>
            <th> Sec/Q </th>
        </tr>
    """

    gs = global_stats()
    html += row_template.substitute(dict(
        label="Global Stats",
            answered=gs.answered,
            correct=gs.correct,
            score="{}%".format(gs.score),
            devStyle="",
            scoreDev="-",
            seconds=gs.seconds,
            secPerQuestion=gs.secondsPerQuestion
    ))

    for stats_dict in stats_list:
        stats = stats_dict['stats']
        devStyle = "color: "
        scoreDev = stats.score - gs.score
        if scoreDev > 0:
            devStyle += "green"
        elif scoreDev < 0:
            devStyle += "red"
        html += row_template.substitute(dict(
            label=stats_dict['label'],
            answered=stats.answered,
            correct=stats.correct,
            score="{}%".format(stats.score),
            scoreDev="{}%".format(scoreDev),
            devStyle=devStyle,
            seconds=stats.seconds,
            secPerQuestion=stats.secondsPerQuestion

        ))
    html += "</table><hr>"
    display(HTML(html))


def named_attempts(name):
    return [a for a in attempts if a.name == name]

def typed_attempts(test_type):
    return [a for a in attempts if a.test_type == test_type]


def print_stats(attempt):
    count = len(named_attempts(attempt.name))
    html = "<h4>{}&mdash;Attempt {}</h4>".format(attempt.name, count)
    display(HTML(html))
    print(attempt.answers)
    student_aggregate_key = attempt.name + " Aggregate"
    student_attempt_key = "{} Attempt".format(attempt.name)
   
    test_type = dimensions[attempt.dimension]['test_type']
    student_type_stats = student_stats_for_type(attempt.name, test_type)
    global_type_stats = global_stats_for_test_type(test_type)

    print_stats_vs_global(
        [
            {
                'label': "{} Attempt".format(attempt.name),
                'stats': attempt
            },
            {
                'label': "{} Summary".format(attempt.name),
                'stats': summaries[attempt.name]
            },
            {
                'label': "{}'s {}s".format(attempt.name, test_type),
                'stats': student_type_stats
            },
            {
                'label': "Global {}s".format(test_type),
                'stats': global_type_stats
            }
        ]
    )


def update_summary(name):
    s = TestStats()
    latest_answers = {}
    seconds = 0
    for r in named_attempts(name):
        for i in range(len(r.answers)):
            # We want the most current stats for each question (latest attempt)
            latest_answers[i] = r.answers[i]
        seconds += r.seconds

    incorrect = len(
        [correct for key, correct in latest_answers.iteritems() if not correct])
    summary = TestStats()
    summary.answered = len(latest_answers)
    summary.incorrect = incorrect
    summary.seconds = seconds
    summaries[name] = summary

def print_test_attempt_stats(test_num):
    attempt = attempts[test_num - 1]
    s = TestStats()


def add_attempt(name, dimension, answers, time):
    attempt = TestAttempt(name, dimension, answers, time)
    attempts.append(attempt)
    update_summary(name)
    print_stats(attempt)


def note(text):
    html = """
        <div style="padding: 20px; background-color: #f7f7f7; margin-top: 20px;">{0}</div>
    """.format(text)
    display(HTML(html))

add_attempt(student_a, 'qbank', [True, True, False, True], 180)
add_attempt(student_b, 'qbank', [True, True, True], 180)
add_attempt(student_c, 'qbank', [True, False], 30)

note("""
    Student A's latest attempts will now == 50%.<br>
    Global answered count should be the same, since A already answered all 4.
    Global correct count should drop by 1.
    """)
add_attempt(student_a, 'qbank', [False], 180)

note("""
    Student A's latest attempts will now == 25%.<br>
    Global answered count should be the same, since A already answered all 4.
    Global correct count should drop by 1.
    """)
add_attempt(student_a, 'fixed', [False, False, False, True], 4)

note("""
    Student B's latest attempts will now == 100%.<br>
    Global answered count should be +=1 (B has now answered all 4).<br>
    Global correct count should be +=1 (B has answered one more question).<b>
    Global fixed answered count should be 8.
    Global fixed avg should be 5/8 (62.5%)""")
add_attempt(student_b, 'fixed', [True, True, True, True], 4)
# Out:
# <h4>Student A&mdash;Attempt 1</h4>
# [True, True, False, True]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 4 </td>
#             <td> 3 </td>
#             <td> 75% </td>
#             <td style=""><em>-</em></td>
#             <td> 180 </td>
#             <td> 45 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Attempt </td>
#             <td> 4 </td>
#             <td> 3 </td>
#             <td> 75% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 180 </td>
#             <td> 45 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Summary </td>
#             <td> 4 </td>
#             <td> 3 </td>
#             <td> 75% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 180 </td>
#             <td> 45 </td>
#         </tr>
#
#         <tr>
#             <td> Student A's qbanks </td>
#             <td> 4 </td>
#             <td> 3 </td>
#             <td> 75% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 180 </td>
#             <td> 45 </td>
#         </tr>
#
#         <tr>
#             <td> Global qbanks </td>
#             <td> 4 </td>
#             <td> 3 </td>
#             <td> 75% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 180 </td>
#             <td> 45 </td>
#         </tr>
#     </table><hr>
# <h4>Student B&mdash;Attempt 1</h4>
# [True, True, True]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 7 </td>
#             <td> 6 </td>
#             <td> 85% </td>
#             <td style=""><em>-</em></td>
#             <td> 360 </td>
#             <td> 51 </td>
#         </tr>
#
#         <tr>
#             <td> Student B Attempt </td>
#             <td> 3 </td>
#             <td> 3 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>15%</em></td>
#             <td> 180 </td>
#             <td> 60 </td>
#         </tr>
#
#         <tr>
#             <td> Student B Summary </td>
#             <td> 3 </td>
#             <td> 3 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>15%</em></td>
#             <td> 180 </td>
#             <td> 60 </td>
#         </tr>
#
#         <tr>
#             <td> Student B's qbanks </td>
#             <td> 3 </td>
#             <td> 3 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>15%</em></td>
#             <td> 180 </td>
#             <td> 60 </td>
#         </tr>
#
#         <tr>
#             <td> Global qbanks </td>
#             <td> 7 </td>
#             <td> 6 </td>
#             <td> 85% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 360 </td>
#             <td> 51 </td>
#         </tr>
#     </table><hr>
# <h4>Student C&mdash;Attempt 1</h4>
# [True, False]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 9 </td>
#             <td> 7 </td>
#             <td> 77% </td>
#             <td style=""><em>-</em></td>
#             <td> 390 </td>
#             <td> 43 </td>
#         </tr>
#
#         <tr>
#             <td> Student C Attempt </td>
#             <td> 2 </td>
#             <td> 1 </td>
#             <td> 50% </td>
#             <td style="color: red"><em>-27%</em></td>
#             <td> 30 </td>
#             <td> 15 </td>
#         </tr>
#
#         <tr>
#             <td> Student C Summary </td>
#             <td> 2 </td>
#             <td> 1 </td>
#             <td> 50% </td>
#             <td style="color: red"><em>-27%</em></td>
#             <td> 30 </td>
#             <td> 15 </td>
#         </tr>
#
#         <tr>
#             <td> Student C's qbanks </td>
#             <td> 2 </td>
#             <td> 1 </td>
#             <td> 50% </td>
#             <td style="color: red"><em>-27%</em></td>
#             <td> 30 </td>
#             <td> 15 </td>
#         </tr>
#
#         <tr>
#             <td> Global qbanks </td>
#             <td> 9 </td>
#             <td> 7 </td>
#             <td> 77% </td>
#             <td style="color: "><em>0%</em></td>
#             <td> 390 </td>
#             <td> 43 </td>
#         </tr>
#     </table><hr>
#         <div style="padding: 20px; background-color: #f7f7f7; margin-top: 20px;">
#     Student A's latest attempts will now == 50%.<br>
#     Global answered count should be the same, since A already answered all 4.
#     Global correct count should drop by 1.
#     </div>
# <h4>Student A&mdash;Attempt 2</h4>
# [False]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 9 </td>
#             <td> 6 </td>
#             <td> 66% </td>
#             <td style=""><em>-</em></td>
#             <td> 570 </td>
#             <td> 63 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Attempt </td>
#             <td> 1 </td>
#             <td> 0 </td>
#             <td> 0% </td>
#             <td style="color: red"><em>-66%</em></td>
#             <td> 180 </td>
#             <td> 180 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Summary </td>
#             <td> 4 </td>
#             <td> 2 </td>
#             <td> 50% </td>
#             <td style="color: red"><em>-16%</em></td>
#             <td> 360 </td>
#             <td> 90 </td>
#         </tr>
#
#         <tr>
#             <td> Student A's qbanks </td>
#             <td> 5 </td>
#             <td> 3 </td>
#             <td> 60% </td>
#             <td style="color: red"><em>-6%</em></td>
#             <td> 360 </td>
#             <td> 72 </td>
#         </tr>
#
#         <tr>
#             <td> Global qbanks </td>
#             <td> 10 </td>
#             <td> 7 </td>
#             <td> 70% </td>
#             <td style="color: green"><em>4%</em></td>
#             <td> 570 </td>
#             <td> 57 </td>
#         </tr>
#     </table><hr>
#         <div style="padding: 20px; background-color: #f7f7f7; margin-top: 20px;">
#     Student A's latest attempts will now == 25%.<br>
#     Global answered count should be the same, since A already answered all 4.
#     Global correct count should drop by 1.
#     </div>
# <h4>Student A&mdash;Attempt 3</h4>
# [False, False, False, True]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 9 </td>
#             <td> 5 </td>
#             <td> 55% </td>
#             <td style=""><em>-</em></td>
#             <td> 574 </td>
#             <td> 63 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Attempt </td>
#             <td> 4 </td>
#             <td> 1 </td>
#             <td> 25% </td>
#             <td style="color: red"><em>-30%</em></td>
#             <td> 4 </td>
#             <td> 1 </td>
#         </tr>
#
#         <tr>
#             <td> Student A Summary </td>
#             <td> 4 </td>
#             <td> 1 </td>
#             <td> 25% </td>
#             <td style="color: red"><em>-30%</em></td>
#             <td> 364 </td>
#             <td> 91 </td>
#         </tr>
#
#         <tr>
#             <td> Student A's fixeds </td>
#             <td> 4 </td>
#             <td> 1 </td>
#             <td> 25% </td>
#             <td style="color: red"><em>-30%</em></td>
#             <td> 4 </td>
#             <td> 1 </td>
#         </tr>
#
#         <tr>
#             <td> Global fixeds </td>
#             <td> 4 </td>
#             <td> 1 </td>
#             <td> 25% </td>
#             <td style="color: red"><em>-30%</em></td>
#             <td> 4 </td>
#             <td> 1 </td>
#         </tr>
#     </table><hr>
#         <div style="padding: 20px; background-color: #f7f7f7; margin-top: 20px;">
#     Student B's latest attempts will now == 100%.<br>
#     Global answered count should be +=1 (B has now answered all 4).<br>
#     Global correct count should be +=1 (B has answered one more question).<b>
#     Global fixed answered count should be 8.
#     Global fixed avg should be 5/8 (62.5%)</div>
# <h4>Student B&mdash;Attempt 2</h4>
# [True, True, True, True]
#     <table>
#         <tr>
#             <th> Stats </th>
#             <th> Answered </th>
#             <th> Correct </th>
#             <th> Score </th>
#             <th> <em>(Deviation)</em> </th>
#             <th> Seconds </th>
#             <th> Sec/Q </th>
#         </tr>
#
#         <tr>
#             <td> Global Stats </td>
#             <td> 10 </td>
#             <td> 6 </td>
#             <td> 60% </td>
#             <td style=""><em>-</em></td>
#             <td> 578 </td>
#             <td> 57 </td>
#         </tr>
#
#         <tr>
#             <td> Student B Attempt </td>
#             <td> 4 </td>
#             <td> 4 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>40%</em></td>
#             <td> 4 </td>
#             <td> 1 </td>
#         </tr>
#
#         <tr>
#             <td> Student B Summary </td>
#             <td> 4 </td>
#             <td> 4 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>40%</em></td>
#             <td> 184 </td>
#             <td> 46 </td>
#         </tr>
#
#         <tr>
#             <td> Student B's fixeds </td>
#             <td> 4 </td>
#             <td> 4 </td>
#             <td> 100% </td>
#             <td style="color: green"><em>40%</em></td>
#             <td> 4 </td>
#             <td> 1 </td>
#         </tr>
#
#         <tr>
#             <td> Global fixeds </td>
#             <td> 8 </td>
#             <td> 5 </td>
#             <td> 62% </td>
#             <td style="color: green"><em>2%</em></td>
#             <td> 8 </td>
#             <td> 1 </td>
#         </tr>
#     </table><hr>
